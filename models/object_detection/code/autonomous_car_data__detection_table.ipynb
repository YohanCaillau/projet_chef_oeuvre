# %% [markdown]
# # Import the packages

# %%
import pandas as pd
import os
from sqlalchemy import create_engine

# %% [markdown]
# # Load Image Data

# %%
df = pd.read_csv('C:/Users/utilisateur/Desktop/Voiture_Autonome/models/object_detection/data/annotations/train_labels_modified.csv', index_col=0)
df
# Out:
#                             person  red_light  green_light  30_speed_sign  \
# image_path
# DSC_0002_1615652012122.JPG       1          1            0              0
# DSC_0002.JPG                     2          1            1              1
# DSC_0003_1615652011057.JPG       1          1            1              1
# DSC_0003.JPG                     2          1            0              1
# DSC_0004_1615652010329.JPG       2          1            1              1
# DSC_0004.JPG                     1          1            1              1
# DSC_0005_1615652009348.JPG       2          0            1              0
# DSC_0005.JPG                     2          1            1              1
# DSC_0006_1615652008327.JPG       3          2            2              2
# DSC_0006.JPG                     2          1            1              1
# DSC_0007_1615652007482.JPG       2          1            1              1
# ...

# %% [markdown]
# # Load Model Data

# %%
df1 = pd.read_csv('C:/Users/utilisateur/Desktop/Voiture_Autonome/models/object_detection/data/model_result/models_register.csv', sep=';', index_col=0)
df1
# Out:
#                                             loss
# model
# ssd_mobilenet_v2_quantized_300x300_coco   2,4541

# %% [markdown]
# ## Create sqlalchemy engine

# %%
#create an engine with the parameters user, password, and database name. 
#This is how we connect and log in to the MySQL database.
from dotenv import load_dotenv

path='C:/Users/utilisateur/Desktop/Voiture_Autonome/bdd/.env'

load_dotenv(dotenv_path=path)
user=os.getenv("MYSQL_USER")
password=os.getenv("MYSQL_PASSWORD")
host=os.getenv("MYSQL_HOST")
database=os.getenv("MYSQL_DATABASE")
port=os.getenv("MYSQL_PORT")

engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user=user,
                               pw=password,
                               db=database))

# %% [markdown]
# ## Insert data into the MySQL table

# %%
# df.to_sql('Object_Detection_Images', con = engine, if_exists = 'append', chunksize = 1000)

# %%
# df1.to_sql('Object_Detection_Models', con = engine, if_exists = 'append', chunksize = 1000)
